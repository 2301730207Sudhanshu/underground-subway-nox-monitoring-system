# %%
#import necessary library
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
#create datset
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X,y=make_moons(n_samples=600,noise=0.05,random_state=42)

# %%
#visualize on scatter plot
plt.scatter(X[:,0],X[:,1],c=y)
plt.xlabel("X1")
plt.ylabel("X2")
plt.title("moon dataset")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.8, random_state=42
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#method 1 to create a neural network
model=Sequential(
    [Dense(16,activation='sigmoid',input_shape=(2,)),
     Dense(32,activation='sigmoid'),
     Dense(24,activation='sigmoid'),
     Dense(8,activation='sigmoid'),
     Dense(1,activation='sigmoid')
     ]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.get_weights()[0]
# Out:
# array([[ 0.04523653, -0.13161805,  0.33939332,  0.34024113,  0.04885095,
#         -0.01919293, -0.04081959,  0.23319393,  0.55138004,  0.46749663,
#          0.01543015, -0.20284697,  0.40978396,  0.5207447 , -0.13079932,
#         -0.17709783],
#        [-0.280554  ,  0.2864372 , -0.42495954,  0.52439904, -0.3540426 ,
#         -0.5613896 ,  0.4232589 , -0.26362842,  0.47667336,  0.3404585 ,
#         -0.28147557,  0.41533208,  0.3690979 , -0.49327108,  0.10497063,
#         -0.21139097]], dtype=float32)

# %%
old_weight=model.get_weights()[0]

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X_train,y_train,batch_size=60,epochs=10,validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.4996 - loss: 0.8244 - val_accuracy: 0.5083 - val_loss: 0.7910
# Epoch 2/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4673 - loss: 0.8226 - val_accuracy: 0.5083 - val_loss: 0.7638
# Epoch 3/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5390 - loss: 0.7334 - val_accuracy: 0.5083 - val_loss: 0.7436
# Epoch 4/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5243 - loss: 0.7280 - val_accuracy: 0.5083 - val_loss: 0.7277
# Epoch 5/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5082 - loss: 0.7240 - val_accuracy: 0.5083 - val_loss: 0.7158
# Epoch 6/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4970 - loss: 0.7186 - val_accuracy: 0.5083 - val_loss: 0.7075
# Epoch 7/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5154 - loss: 0.7033 - val_accuracy: 0.5083 - val_loss: 0.7022
# Epoch 8/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4982 - loss: 0.7040 - val_accuracy: 0.5083 - val_loss: 0.6983
# Epoch 9/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4895 - loss: 0.7018 - val_accuracy: 0.5083 - val_loss: 0.6957
# Epoch 10/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5040 - loss: 0.6959 - val_accuracy: 0.5083 - val_loss: 0.6943

# %%
X_train.shape
# Out:
# (480, 2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (480, 2)
# (480,)

# %%
model.get_weights()[0]
# Out:
# array([[-0.04023738, -0.21253456,  0.3753306 ,  0.2566449 ,  0.09221476,
#          0.04422578, -0.1325698 ,  0.14112863,  0.6319052 ,  0.39187157,
#         -0.07522961, -0.15291026,  0.34904182,  0.43111816, -0.16394389,
#         -0.25043094],
#        [-0.2024229 ,  0.3582148 , -0.45890185,  0.60081494, -0.3932397 ,
#         -0.6151786 ,  0.5085668 , -0.17726873,  0.39925736,  0.41008905,
#         -0.1968359 ,  0.36733195,  0.42150947, -0.4095278 ,  0.12920299,
#         -0.14793883]], dtype=float32)

# %%
model.evaluate(X_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.5242 - loss: 0.6920
# [0.6942985653877258, 0.5083333253860474]

# %%
model_2=Sequential(
    [Dense(16,activation='relu',input_shape=(2,)),
     Dense(32,activation='relu'),
     Dense(24,activation='relu'),
     Dense(8,activation='relu'),
     Dense(1,activation='sigmoid')
     ]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_2.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model_2.fit(X_train,y_train,batch_size=60,epochs=10,validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.5463 - loss: 0.6723 - val_accuracy: 0.7750 - val_loss: 0.6489
# Epoch 2/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8034 - loss: 0.6386 - val_accuracy: 0.8250 - val_loss: 0.6163
# Epoch 3/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8280 - loss: 0.6056 - val_accuracy: 0.8417 - val_loss: 0.5828
# Epoch 4/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8289 - loss: 0.5693 - val_accuracy: 0.8417 - val_loss: 0.5431
# Epoch 5/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8387 - loss: 0.5289 - val_accuracy: 0.8500 - val_loss: 0.5009
# Epoch 6/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8396 - loss: 0.4791 - val_accuracy: 0.8500 - val_loss: 0.4583
# Epoch 7/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8407 - loss: 0.4394 - val_accuracy: 0.8417 - val_loss: 0.4176
# Epoch 8/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8487 - loss: 0.3906 - val_accuracy: 0.8500 - val_loss: 0.3798
# Epoch 9/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8243 - loss: 0.3761 - val_accuracy: 0.8500 - val_loss: 0.3479
# Epoch 10/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8561 - loss: 0.3193 - val_accuracy: 0.8417 - val_loss: 0.3218

# %%
new_weights=model_2.get_weights()[0]

# %%
model_2.fit(X_train,y_train,batch_size=60,epochs=50,validation_data=(X_test,y_test))
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.7690e-04 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.2789e-04 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.8449e-04 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.4582e-04 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.2314e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.4959e-04 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.8283e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.1005e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.9599e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.2620e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.3669e-04 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.7742e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.2082e-04 - val_accuracy: 1.0000 - val_loss: 9.6601e-04
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.7672e-04 - val_accuracy: 1.0000 - val_loss: 8.9654e-04
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.3353e-04 - val_accuracy: 1.0000 - val_loss: 9.1733e-04
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.8690e-04 - val_accuracy: 1.0000 - val_loss: 9.5254e-04
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.4401e-04 - val_accuracy: 1.0000 - val_loss: 9.4462e-04
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.3452e-04 - val_accuracy: 1.0000 - val_loss: 9.2355e-04
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.7315e-04 - val_accuracy: 1.0000 - val_loss: 8.5717e-04
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.5789e-04 - val_accuracy: 1.0000 - val_loss: 8.3971e-04
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.1764e-04 - val_accuracy: 1.0000 - val_loss: 7.6700e-04
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 4.9413e-04 - val_accuracy: 1.0000 - val_loss: 7.4437e-04
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.3735e-04 - val_accuracy: 1.0000 - val_loss: 8.0088e-04
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.0392e-04 - val_accuracy: 1.0000 - val_loss: 8.0979e-04
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 7.9030e-04 - val_accuracy: 1.0000 - val_loss: 8.5279e-04
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.0614e-04 - val_accuracy: 1.0000 - val_loss: 7.7549e-04
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 4.2776e-04 - val_accuracy: 1.0000 - val_loss: 7.2357e-04
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 4.8168e-04 - val_accuracy: 1.0000 - val_loss: 7.3148e-04
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.7343e-04 - val_accuracy: 1.0000 - val_loss: 7.3324e-04
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.3031e-04 - val_accuracy: 1.0000 - val_loss: 6.9090e-04
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 6.1124e-04 - val_accuracy: 1.0000 - val_loss: 7.2789e-04
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.2512e-04 - val_accuracy: 1.0000 - val_loss: 6.9785e-04
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 5.5540e-04 - val_accuracy: 1.0000 - val_loss: 6.8804e-04
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.7303e-04 - val_accuracy: 1.0000 - val_loss: 6.5540e-04
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.3175e-04 - val_accuracy: 1.0000 - val_loss: 6.4975e-04
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 3.8657e-04 - val_accuracy: 1.0000 - val_loss: 6.1440e-04
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 4.0406e-04 - val_accuracy: 1.0000 - val_loss: 5.9511e-04
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.6433e-04 - val_accuracy: 1.0000 - val_loss: 6.0474e-04
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.6980e-04 - val_accuracy: 1.0000 - val_loss: 6.0757e-04
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.4138e-04 - val_accuracy: 1.0000 - val_loss: 6.2380e-04
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.2919e-04 - val_accuracy: 1.0000 - val_loss: 5.8799e-04
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.0464e-04 - val_accuracy: 1.0000 - val_loss: 6.0675e-04
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.0791e-04 - val_accuracy: 1.0000 - val_loss: 5.8687e-04
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.7038e-04 - val_accuracy: 1.0000 - val_loss: 5.6942e-04
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.2017e-04 - val_accuracy: 1.0000 - val_loss: 5.2951e-04

# %%
old_weight==new_weights
# Out:
# array([[False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False]])

# %%
model_2.evaluate(X_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8648 - loss: 0.2977
# [0.32182711362838745, 0.8416666388511658]

# %%
model.evaluate(X_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5242 - loss: 0.6920
# [0.6942985653877258, 0.5083333253860474]

# %%
model_2.evaluate(X_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 5.0502e-04
# [0.000529507000464946, 1.0]
